# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Load Excel dataframe (replace 'input_data.xlsx' with your Excel file)
data = pd.read_excel("Samuel_Project/sample_input.xlsx")

# Extract X and Y data from the dataframe
X = data['X']
Y = data['Y']

# Perform simple linear regression
slope, intercept, r_value, p_value, std_err = linregress(X, Y)

# Print regression parameters
print("Slope:", slope)
print("Intercept:", intercept)
print("R-squared:", r_value**2)
print("P-value:", p_value)
print("Standard error:", std_err)

# Plot the data and regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X, y=Y, label='Data')
sns.lineplot(x=X, y=slope*X + intercept, color='red', label='Linear Regression')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()
# Out:
# Slope: 0.0022289411076877835
# Intercept: 0.8047420435519622
# R-squared: 0.5499633698024625
# P-value: 0.014085067594564675
# Standard error: 0.0007128705116705443
