# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load Excel dataframe (replace 'input_data.xlsx' with your Excel file)
data = pd.read_excel('Samuel_Project/sample_input.xlsx')

# Plot the data
sns.lineplot(x='X', y='Y', data=data)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Excel Dataframe")
plt.show()

# Calculate area under the curve using the trapezoidal rule
area = np.trapz(data['Y'], x=data['X'])
print("Area under the curve:", area)
# Out:
# Area under the curve: 2218.6126935
